# %% [markdown]
# ## Importarea datelor

# %%
from sklearn import tree, datasets, metrics
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets, tree, svm, neural_network

from sklearn import ensemble

# %%
date = []
etichete = []

# %% [markdown]
# ## Citirea bazei de date

# %%
with open('auto-mpg.data','r') as f:
    for line in f:
        list_of_data = line.split()
        # print(list_of_data)
        list_of_data = [float(i) if i != '?' else np.nan for i in list_of_data[0:8]]
        date.append(list_of_data[1:8])
        etichete.append(list_of_data[0])

# %%
print(date[0])
print(len(date))
print(etichete[0])
print(len(etichete))
# for index, data in enumerate(date):
#     if '?' in data:
#         print(index)
# Out:
# [8.0, 307.0, 130.0, 3504.0, 12.0, 70.0, 1.0]
# 398
# 18.0
# 398

# %% [markdown]
# ## Inlocuirea valorilor lipsa

# %%
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer(strategy='most_frequent')
date = my_imputer.fit_transform(date)

# %% [markdown]
# ## Impartirea datelor

# %%
date_train = date[:298, :]
date_test = date[298:, :]

etichete_train = etichete[:298]
etichete_test = etichete[298:]

# %% [markdown]
# ## Random Forest

# %%
regr = ensemble.RandomForestRegressor()
regr.fit(date_train, etichete_train)
# Out:
# RandomForestRegressor()

# %%
predictii = regr.predict(date_test)
Err = metrics.mean_squared_error(y_true=etichete_test, y_pred=predictii)
print('Eroarea patratica medie =', Err)
# Out:
# Eroarea patratica medie = 44.50899224999998

# %% [markdown]
# ## SVM

# %%
regr = svm.SVR()
regr.fit(date_train, etichete_train)
# Out:
# SVR()

# %%
predictii = regr.predict(date_test)
Err = metrics.mean_squared_error(y_true=etichete_test, y_pred=predictii)
print('Eroarea patratica medie =', Err)
# Out:
# Eroarea patratica medie = 72.53758345235632

# %% [markdown]
# ## MLP

# %%
regr = neural_network.MLPRegressor(learning_rate_init=0.01)
regr.fit(date_train,etichete_train)
# Out:
# MLPRegressor(learning_rate_init=0.01)

# %%
predictii = regr.predict(date_test)
Err = metrics.mean_squared_error(y_true=etichete_test, y_pred=predictii)
print('Eroarea patratica medie =', Err)
# Out:
# Eroarea patratica medie = 28.289889924149357
